# %%
import pandas as pd

# %%
session_details = pd.read_json("central_banks_01_03_2014.json")

# %%
session_details
# Out:
#                         central_bank_name       date  \
# 0                                     NaN 2014-03-28
# 1                           Bank of Italy 2014-03-18
# 2                                     NaN 2014-03-28
# 3                 Central Bank of Iceland 2014-01-27
# 4             Reserve Bank of New Zealand 2014-03-05
# 5             Reserve Bank of New Zealand 2014-03-27
# 6                   Reserve Bank of India 2014-01-27
# 7                    Reserve Bank of Fiji 2014-03-31
# 8                                     NaN 2014-03-17
# 9          Federal Reserve Bank of Dallas 2014-02-13
# 10                         Bank of Mexico 2014-03-05
# 11            Reserve Bank of New Zealand 2014-03-26
# 12                          Bank of Japan 2014-03-28
# 13        Federal Reserve Bank of Chicago 2014-03-28
# 14                         Bank of Uganda 2014-03-31
# 15                                    NaN 2014-03-31
# 16                  Reserve Bank of India 2014-01-22
# ...

# %%
import gender_guesser.detector as gender

# %%
print(d.get_gender("Pamela"))
