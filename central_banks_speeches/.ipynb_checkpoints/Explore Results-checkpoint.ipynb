# %%
import pandas as pd

# %%
session_details = pd.read_json("central_banks.json")

# %%
session_details
# Out:
#                                      central_banck_name       date  \
# 0                                                   NaN 2020-08-07
# 1                                                   NaN 2020-08-07
# 2                Basel Committee on Banking Supervision 2020-08-07
# 3                Basel Committee on Banking Supervision 2020-08-07
# 4                                        Bank of Canada 2020-08-07
# 5                                        Bank of Canada 2020-08-07
# 6                                                   NaN 2020-08-19
# 7                                                   NaN 2020-08-07
# 8                                                   NaN 2020-08-07
# 9                           Reserve Bank of New Zealand 2020-01-30
# 10               Basel Committee on Banking Supervision 2020-01-30
# 11                                European Central Bank 2020-01-30
# 12                                       Bank of Canada 2020-01-30
# ...
