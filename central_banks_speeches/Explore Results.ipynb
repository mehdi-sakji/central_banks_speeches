# %%
import pandas as pd

# %%
session_details = pd.read_json("central_banks_2.json")

# %%
session_details
# Out:
#                                      central_banck_name       date  \
# 0                                         Bank of Italy 2020-08-17
# 1                                 Central Bank of Chile 2020-08-18
# 2                                                   NaN 2020-08-19
# 3                           Reserve Bank of New Zealand 2020-08-20
# 4                                                   NaN 2020-08-24
# 5                                                   NaN 2020-08-07
# 6                                                   NaN 2020-08-07
# 7                                                   NaN 2020-08-07
# 8                                                   NaN 2020-08-07
# 9                Basel Committee on Banking Supervision 2020-08-07
# 10                                                  NaN 2020-08-04
# 11                                                  NaN 2020-08-07
# 12                                                  NaN 2020-07-15
# ...
